# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# '/home/jia/Desktop/git/STB_social_media_analytics/qiongyou/output/200215_205917/reviews'

# %%
#get Ctrip overall review data
os.chdir('/home/jia/Desktop/git/STB_social_media_analytics/ctrip/200216_102752/reviews')
Ctrip_POIs=pd.read_csv('./1.csv')

#read all the review files
path = '/home/jia/Desktop/git/STB_social_media_analytics/ctrip/200216_102752/reviews'
for i in range(2,519):
    try:
        Ctrip_POIs=Ctrip_POIs.append(pd.read_csv(path+'/{}.csv'.format(i)))
    except:
        print(str(i)+' not exist')
        continue
# Out:
# 373 not exist

# %%
#get QY overall review data
os.chdir('/home/jia/Desktop/git/STB_social_media_analytics/qiongyou/output/200215_205917/reviews')
QY_POIs=pd.read_csv('./0.csv')

# %%
path = '/home/jia/Desktop/git/STB_social_media_analytics/qiongyou/output/200215_205917/reviews'
for i in range(1,354):
    try:
        QY_POIs=QY_POIs.append(pd.read_csv(path+'/{}.csv'.format(i)))
    except:
        print(str(i)+' not exist')
        continue
QY_POIs=QY_POIs.drop(col,axis=1)

# %%
os.chdir('/home/jia/Desktop/git/STB_social_media_analytics/experimentation/jiaxin_experiment/descriptive_stats')
Ctrip_POIs.to_csv('./ctrip_pois.csv')
QY_POIs.to_csv('./qy_pois.csv')

# %%
QY_POIs.head(20)
# Out:
#    POI_INDEX               REVIEWER_URL  \
# 0          0   //www.qyer.com/u/6303027
# 1          0   //www.qyer.com/u/2759091
# 2          0   //www.qyer.com/u/9738108
# 3          0  //www.qyer.com/u/12398214
# 4          0   //www.qyer.com/u/3618817
# 5          0   //www.qyer.com/u/1601481
# 6          0  //www.qyer.com/u/12308347
# 7          0   //www.qyer.com/u/2925158
# 8          0   //www.qyer.com/u/1523743
# 9          0  //www.qyer.com/u/12089844
# 10         0   //www.qyer.com/u/3615108
# 11         0   //www.qyer.com/u/2932391
# 12         0   //www.qyer.com/u/6910942
# 13         0   //www.qyer.com/u/9719353
# 14         0   //www.qyer.com/u/5228748
# 15         0   //www.qyer.com/u/2822434
# 16         0  //www.qyer.com/u/11310163
# 17         0  //www.qyer.com/u/11257458
# 18         0   //www.qyer.com/u/5948283
# 19         0  //www.qyer.com/u/11110319
#
#                                           REVIEW_BODY  \
# ...

# %%
col=[]
for i in range(8,34):
    col+=['Unnamed: {}'.format(i)]
col
# Out:
# ['Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33']
