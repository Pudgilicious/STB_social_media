# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/home/jia/Desktop/git/STB_social_media_analytics/experimentation/jiaxin_experiment'

# %%
raw=pd.read_csv('./aggregate_list/ctrip_list.csv')
new=pd.read_csv('./aggregate_list/20200213_TB_SOCIAL_CTRIP_CRAWL_LIST.csv')
raw=raw.drop_duplicates(subset=['POI','link'])
new=new.drop_duplicates()

# %%
raw.head()
# Out:
#    INDEX       POI                            link  \
# 0      0   新加坡环球影城    /sight/sentosa776/75830.html
# 1      1  新加坡滨海湾花园  /sight/singapore53/132782.html
# 2      2      圣淘沙岛   /sight/singapore53/47929.html
# 3      3       乌节路  /sight/singapore53/108118.html
# 4      4      克拉码头    /sight/singapore53/3654.html
#
#                                     num_reviews
# 0  \n                                (16364条点评)
# 1   \n                                (6378条点评)
# 2   \n                                (3992条点评)
# 3   \n                                (2103条点评)
# 4   \n                                (2461条点评)

# %%
raw.describe()
# Out:
#              INDEX
# count  1506.000000
# mean    802.345286
# std     484.319878
# min       0.000000
# 25%     377.250000
# 50%     792.500000
# 75%    1221.750000
# max    1665.000000

# %%
new.head()
# Out:
#    POI_INDEX  WEBSITE_INDEX                     POI_NAME  \
# 0          1              2  Universal Studios Singapore
# 1          2              2         Singapore Gardens by
# 2          3              2               Sentosa Island
# 3          4              2                 Orchard Road
# 4          5              2                  Clarke Quay
#
#                               URL POI_GOOGLE_TRANSLATE_ENGLISH_NAME  \
# 0    /sight/sentosa776/75830.html       Universal Studios Singapore
# 1  /sight/singapore53/132782.html              Singapore Gardens by
# 2   /sight/singapore53/47929.html                    Sentosa Island
# 3  /sight/singapore53/108118.html                      Orchard Road
# 4    /sight/singapore53/3654.html                       Clarke Quay
#
#   POI_CHINESE_NAME ENG_NAME_SPACE
# 0          新加坡环球影城            NaN
# 1         新加坡滨海湾花园            NaN
# 2             圣淘沙岛            NaN
# 3              乌节路   Orchard Road
# 4             克拉码头            NaN

# %%
new.describe()
# Out:
#         POI_INDEX  WEBSITE_INDEX
# count  517.000000          517.0
# mean   259.280464            2.0
# std    149.739453            0.0
# min      1.000000            2.0
# 25%    130.000000            2.0
# 50%    259.000000            2.0
# 75%    389.000000            2.0
# max    518.000000            2.0

# %%
left=pd.merge(new,raw,"left",left_on=['URL','POI_CHINESE_NAME'],right_on=['link','POI'])

# %%
left.describe()
# Out:
#         POI_INDEX  WEBSITE_INDEX       INDEX
# count  517.000000          517.0  508.000000
# mean   259.280464            2.0  259.348425
# std    149.739453            0.0  153.692804
# min      1.000000            2.0    0.000000
# 25%    130.000000            2.0  126.750000
# 50%    259.000000            2.0  254.500000
# 75%    389.000000            2.0  391.250000
# max    518.000000            2.0  534.000000

# %%
left.head()
# Out:
#    POI_INDEX  WEBSITE_INDEX                     POI_NAME  \
# 0          1              2  Universal Studios Singapore
# 1          2              2         Singapore Gardens by
# 2          3              2               Sentosa Island
# 3          4              2                 Orchard Road
# 4          5              2                  Clarke Quay
#
#                               URL POI_GOOGLE_TRANSLATE_ENGLISH_NAME  \
# 0    /sight/sentosa776/75830.html       Universal Studios Singapore
# 1  /sight/singapore53/132782.html              Singapore Gardens by
# 2   /sight/singapore53/47929.html                    Sentosa Island
# 3  /sight/singapore53/108118.html                      Orchard Road
# 4    /sight/singapore53/3654.html                       Clarke Quay
#
#   POI_CHINESE_NAME ENG_NAME_SPACE  INDEX       POI  \
# 0          新加坡环球影城            NaN    0.0   新加坡环球影城
# 1         新加坡滨海湾花园            NaN    1.0  新加坡滨海湾花园
# 2             圣淘沙岛            NaN    2.0      圣淘沙岛
# 3              乌节路   Orchard Road    3.0       乌节路
# 4             克拉码头            NaN    4.0      克拉码头
#
#                              link  \
# 0    /sight/sentosa776/75830.html
# 1  /sight/singapore53/132782.html
# 2   /sight/singapore53/47929.html
# 3  /sight/singapore53/108118.html
# 4    /sight/singapore53/3654.html
#
#                                     num_reviews
# 0  \n                                (16364条点评)
# 1   \n                                (6378条点评)
# 2   \n                                (3992条点评)
# 3   \n                                (2103条点评)
# 4   \n                                (2461条点评)

# %%
left.insert(11,'IS_PRIORITIZED',1)

# %%
left.loc[left.INDEX < 96.0, 'IS_PRIORITIZED'] = 0

# %%
left.drop([left.columns[7],left.columns[8],left.columns[9],left.columns[10]],axis="columns")
# Out:
#      POI_INDEX  WEBSITE_INDEX                     POI_NAME  \
# 0            1              2  Universal Studios Singapore
# 1            2              2         Singapore Gardens by
# 2            3              2               Sentosa Island
# 3            4              2                 Orchard Road
# 4            5              2                  Clarke Quay
# ..         ...            ...                          ...
# 512        514              2  Singapore Chinese Orchestra
# 513        515              2                Beauty Empire
# 514        516              2         Renaza Hair Nail Spa
# 515        517              2               Admiralty Park
# 516        518              2     Singapore City Bike Tour
#
#                                   URL POI_GOOGLE_TRANSLATE_ENGLISH_NAME  \
# 0        /sight/sentosa776/75830.html       Universal Studios Singapore
# 1      /sight/singapore53/132782.html              Singapore Gardens by
# 2       /sight/singapore53/47929.html                    Sentosa Island
# 3      /sight/singapore53/108118.html                      Orchard Road
# 4        /sight/singapore53/3654.html                       Clarke Quay
# ..                                ...                               ...
# 512   /sight/singapore53/4803984.html       Singapore Chinese Orchestra
# 513   /sight/singapore53/4823360.html                     Beauty Empire
# 514   /sight/singapore53/4778313.html            Renaza Hair & Nail Spa
# 515   /sight/singapore53/4919565.html                    Admiralty Park
# 516  /sight/singapore53/71564484.html          Singapore City Bike Tour
#
#                 POI_CHINESE_NAME               ENG_NAME_SPACE  IS_PRIORITIZED
# 0                        新加坡环球影城                          NaN               0
# 1                       新加坡滨海湾花园                          NaN               0
# 2                           圣淘沙岛                          NaN               0
# 3                            乌节路                 Orchard Road               0
# 4                           克拉码头                          NaN               0
# ..                           ...                          ...             ...
# 512  Singapore Chinese Orchestra  Singapore Chinese Orchestra               1
# 513                Beauty Empire                Beauty Empire               1
# 514       Renaza Hair & Nail Spa         Renaza Hair Nail Spa               1
# 515               Admiralty Park               Admiralty Park               1
# 516     Singapore City Bike Tour     Singapore City Bike Tour               1
#
# [517 rows x 8 columns]

# %%
left.head()
# Out:
#    POI_INDEX  WEBSITE_INDEX                     POI_NAME  \
# 0          1              2  Universal Studios Singapore
# 1          2              2         Singapore Gardens by
# 2          3              2               Sentosa Island
# 3          4              2                 Orchard Road
# 4          5              2                  Clarke Quay
#
#                               URL POI_GOOGLE_TRANSLATE_ENGLISH_NAME  \
# 0    /sight/sentosa776/75830.html       Universal Studios Singapore
# 1  /sight/singapore53/132782.html              Singapore Gardens by
# 2   /sight/singapore53/47929.html                    Sentosa Island
# 3  /sight/singapore53/108118.html                      Orchard Road
# 4    /sight/singapore53/3654.html                       Clarke Quay
#
#   POI_CHINESE_NAME ENG_NAME_SPACE  INDEX       POI  \
# 0          新加坡环球影城            NaN    0.0   新加坡环球影城
# 1         新加坡滨海湾花园            NaN    1.0  新加坡滨海湾花园
# 2             圣淘沙岛            NaN    2.0      圣淘沙岛
# 3              乌节路   Orchard Road    3.0       乌节路
# 4             克拉码头            NaN    4.0      克拉码头
#
#                              link  \
# 0    /sight/sentosa776/75830.html
# 1  /sight/singapore53/132782.html
# 2   /sight/singapore53/47929.html
# 3  /sight/singapore53/108118.html
# 4    /sight/singapore53/3654.html
#
#                                     num_reviews  IS_PRIORITIZED
# 0  \n                                (16364条点评)               0
# 1   \n                                (6378条点评)               0
# 2   \n                                (3992条点评)               0
# 3   \n                                (2103条点评)               0
# 4   \n                                (2461条点评)               0

# %%
left.to_csv('./aggregate_list/0214_prio_list.csv')
