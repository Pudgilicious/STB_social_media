# %%
import pandas as pd
origin=pd.read_csv('./vocab.csv')

# %%
euclidean=pd.read_csv('./euclidean_distance.csv')

# %% [markdown]
# df=pd.merge(left=origin, right=euclidean, "left")

# %%
df_euc=origin.merge(right=euclidean, how="inner",on=['CAT_NAME','KEYWORD'])

# %%
df_euc
# Out:
#     KEYWORD  COUNT  SENTIMENT_KEYWORD_AGG_INDEX  \
# 0        地方   4424                            2
# 1        孩子   3456                            3
# 2        景点   2498                            7
# 3        动物   2125                            8
# 4        项目   2024                            9
# ..      ...    ...                          ...
# 117     大商场     64                          795
# 118      大桥     63                          815
# 119    蓝天白云     62                          833
# 120    绿树成荫     61                          847
# 121     免税店     57                          892
#
#                           CAT_NAME  ASPECT_CATEGORY  REQUIRE_CONTEXT  \
# 0                Sightseeing/Place              NaN              NaN
# 1    Family/Childre family/Friends              NaN              NaN
# 2                Sightseeing/Place              NaN              NaN
# 3                Sightseeing/Place              NaN              NaN
# ...

# %%
manhattan=pd.read_csv('./manhattan_distance.csv')
df_man=origin.merge(right=manhattan, how="inner",on=['CAT_NAME','KEYWORD'])
df_man
# Out:
#     KEYWORD  COUNT  SENTIMENT_KEYWORD_AGG_INDEX  \
# 0        地方   4424                            2
# 1        孩子   3456                            3
# 2        景点   2498                            7
# 3        动物   2125                            8
# 4        项目   2024                            9
# ..      ...    ...                          ...
# 113     大商场     64                          795
# 114      大桥     63                          815
# 115    蓝天白云     62                          833
# 116    绿树成荫     61                          847
# 117     免税店     57                          892
#
#                           CAT_NAME  ASPECT_CATEGORY  REQUIRE_CONTEXT  \
# 0                Sightseeing/Place              NaN              NaN
# 1    Family/Childre family/Friends              NaN              NaN
# 2                Sightseeing/Place              NaN              NaN
# 3                Sightseeing/Place              NaN              NaN
# ...

# %%
cosine=pd.read_csv('./cosine_similarity.csv')
df_cos=origin.merge(right=cosine, how="inner",on=['CAT_NAME','KEYWORD'])
df_cos
# Out:
#     KEYWORD  COUNT  SENTIMENT_KEYWORD_AGG_INDEX  \
# 0        地方   4424                            2
# 1        孩子   3456                            3
# 2        景点   2498                            7
# 3        动物   2125                            8
# 4        项目   2024                            9
# ..      ...    ...                          ...
# 117     大商场     64                          795
# 118      大桥     63                          815
# 119    蓝天白云     62                          833
# 120    绿树成荫     61                          847
# 121     免税店     57                          892
#
#                           CAT_NAME  ASPECT_CATEGORY  REQUIRE_CONTEXT  \
# 0                Sightseeing/Place              NaN              NaN
# 1    Family/Childre family/Friends              NaN              NaN
# 2                Sightseeing/Place              NaN              NaN
# 3                Sightseeing/Place              NaN              NaN
# ...

# %%
cor=pd.read_csv('./correlation.csv')
df_cor=origin.merge(right=cor, how="inner",on=['CAT_NAME','KEYWORD'])
df_cor
# Out:
#   KEYWORD  COUNT  SENTIMENT_KEYWORD_AGG_INDEX                  CAT_NAME  \
# 0    空中花园    161                          310         Sightseeing/Place
# 1  圣安德烈教堂    136                          367         Sightseeing/Place
# 2      座桥    101                          479         Sightseeing/Place
# 3      地面     64                          793  Environment and Ambience
# 4    风景优美     58                          889         Sightseeing/Place
#
#    ASPECT_CATEGORY  REQUIRE_CONTEXT  CAT_INDEX
# 0              NaN              NaN         10
# 1              NaN              NaN         10
# 2              NaN              NaN         10
# 3              NaN              NaN          3
# 4              NaN              NaN         10
