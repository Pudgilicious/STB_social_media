# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions, KeywordsOptions

import pandas as pd
from pandas.io.json import json_normalize

# %%
authenticator = IAMAuthenticator('bkC6hyTVS4qonY34vS0d8Q5F2YY4Kz9m0fyj1cN-5VFw')

natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://gateway.watsonplatform.net/natural-language-understanding/api/v1/analyze?version=2019-07-12')

text = """
Gardens by the Bay is a stunning place and a real credit to the city. The skywalk and Cloud Forest are both excellent. We decided not to do the Flower Dome and were glad we’d made that decision as we spent a long time in the Cloud Forest.

The above was on our second visit. The first was on Christmas night and the whole site was absolutely packed. Queues for the paid attractions were incredible. We had dinner at Satay by the Bay, which wasn’t too crowded at about 7pm, and then fought our way to the MRT station. Worth noting that Google maps has a feature that shows how busy a place is, and that was saying twice as busy as normally at the same time. We should have paid attention. A useful tool.

Definitely go, but pick your time.
"""

response = natural_language_understanding.analyze(
    text=text,
    features=Features(entities=EntitiesOptions(emotion=True, sentiment=True, limit=100000), keywords=KeywordsOptions(emotion=True, sentiment=True, limit=100000))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 740,
#     "features": 2
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "Google maps",
#       "sentiment": {
#         "score": -0.58405,
#         "label": "negative"
#       },
#       "relevance": 0.787506,
#       "emotion": {
#         "sadness": 0.356046,
#         "joy": 0.276475,
#         "fear": 0.042222,
#         "disgust": 0.020566,
#         "anger": 0.106622
#       },
#       "count": 1
#     },
#     {
#       "text": "Christmas night",
#       "sentiment": {
#         "score": 0.848073,
#         "label": "positive"
#       },
#       "relevance": 0.65692,
#       "emotion": {
#         "sadness": 0.142284,
#         "joy": 0.672585,
#         "fear": 0.048696,
#         "disgust": 0.124595,
#         "anger": 0.058746
#       },
#       "count": 1
#     },
#     {
#       "text": "Flower Dome",
#       "sentiment": {
#         "score": 0.724732,
#         "label": "positive"
#       },
#       "relevance": 0.636486,
#       "emotion": {
#         "sadness": 0.098599,
#         "joy": 0.778855,
#         "fear": 0.060311,
#         "disgust": 0.02391,
#         "anger": 0.023072
#       },
#       "count": 1
#     },
#     {
#       "text": "long time",
#       "sentiment": {
#         "score": 0.724732,
#         "label": "positive"
#       },
#       "relevance": 0.605059,
#       "emotion": {
#         "sadness": 0.098599,
#         "joy": 0.778855,
#         "fear": 0.060311,
#         "disgust": 0.02391,
#         "anger": 0.023072
#       },
#       "count": 1
#     },
#     {
#       "text": "useful tool",
#       "sentiment": {
#         "score": 0.83736,
#         "label": "positive"
#       },
#       "relevance": 0.602506,
#       "emotion": {
#         "sadness": 0.147367,
#         "joy": 0.558533,
#         "fear": 0.059763,
#         "disgust": 0.10218,
#         "anger": 0.056833
#       },
#       "count": 1
#     },
#     {
#       "text": "Cloud Forest",
#       "sentiment": {
#         "score": 0.86014,
#         "label": "positive"
#       },
#       "relevance": 0.601793,
#       "emotion": {
#         "sadness": 0.049122,
#         "joy": 0.858749,
#         "fear": 0.039461,
#         "disgust": 0.020585,
#         "anger": 0.012998
#       },
#       "count": 2
#     },
#     {
#       "text": "stunning place",
#       "sentiment": {
#         "score": 0.986622,
#         "label": "positive"
#       },
#       "relevance": 0.590876,
#       "emotion": {
#         "sadness": 0.115967,
#         "joy": 0.745994,
#         "fear": 0.053952,
#         "disgust": 0.017398,
#         "anger": 0.025789
#       },
#       "count": 1
#     },
#     {
#       "text": "second visit",
#       "sentiment": {
#         "score": 0.848073,
#         "label": "positive"
#       },
#       "relevance": 0.585235,
#       "emotion": {
#         "sadness": 0.127068,
#         "joy": 0.301353,
#         "fear": 0.052929,
#         "disgust": 0.14464,
#         "anger": 0.043257
#       },
#       "count": 1
#     },
#     {
#       "text": "MRT station",
#       "sentiment": {
#         "score": -0.777339,
#         "label": "negative"
#       },
#       "relevance": 0.57709,
#       "emotion": {
#         "sadness": 0.212864,
#         "joy": 0.293073,
#         "fear": 0.115059,
#         "disgust": 0.108649,
#         "anger": 0.312103
#       },
#       "count": 1
#     },
#     {
#       "text": "paid attractions",
#       "sentiment": {
#         "score": 0.92877,
#         "label": "positive"
#       },
#       "relevance": 0.566158,
#       "emotion": {
#         "sadness": 0.032162,
#         "joy": 0.763132,
#         "fear": 0.028307,
#         "disgust": 0.055176,
#         "anger": 0.060813
#       },
#       "count": 1
#     },
#     {
#       "text": "Bay",
#       "sentiment": {
#         "score": 0.410452,
#         "mixed": "1",
#         "label": "positive"
#       },
#       "relevance": 0.544072,
#       "emotion": {
#         "sadness": 0.137327,
#         "joy": 0.691357,
#         "fear": 0.053887,
#         "disgust": 0.03447,
#         "anger": 0.098064
#       },
#       "count": 2
#     },
#     {
#       "text": "dinner",
#       "sentiment": {
#         "score": -0.919753,
#         "label": "negative"
#       },
#       "relevance": 0.542642,
#       "emotion": {
#         "sadness": 0.212864,
#         "joy": 0.293073,
#         "fear": 0.115059,
#         "disgust": 0.108649,
#         "anger": 0.312103
#       },
#       "count": 1
#     },
#     {
#       "text": "Queues",
#       "sentiment": {
#         "score": 0.92877,
#         "label": "positive"
#       },
#       "relevance": 0.540512,
#       "emotion": {
#         "sadness": 0.032162,
#         "joy": 0.763132,
#         "fear": 0.028307,
#         "disgust": 0.055176,
#         "anger": 0.060813
#       },
#       "count": 1
#     },
#     {
#       "text": "Gardens",
#       "sentiment": {
#         "score": 0.986622,
#         "label": "positive"
#       },
#       "relevance": 0.534535,
#       "emotion": {
#         "sadness": 0.115967,
#         "joy": 0.745994,
#         "fear": 0.053952,
#         "disgust": 0.017398,
#         "anger": 0.025789
#       },
#       "count": 1
#     },
#     {
#       "text": "Satay",
#       "sentiment": {
#         "score": -0.919753,
#         "label": "negative"
#       },
#       "relevance": 0.53258,
#       "emotion": {
#         "sadness": 0.212864,
#         "joy": 0.293073,
#         "fear": 0.115059,
#         "disgust": 0.108649,
#         "anger": 0.312103
#       },
#       "count": 1
#     },
#     {
#       "text": "feature",
#       "sentiment": {
#         "score": -0.58405,
#         "label": "negative"
#       },
#       "relevance": 0.523991,
#       "emotion": {
#         "sadness": 0.356046,
#         "joy": 0.276475,
#         "fear": 0.042222,
#         "disgust": 0.020566,
#         "anger": 0.106622
#       },
#       "count": 1
#     },
#     {
#       "text": "decision",
#       "sentiment": {
#         "score": 0.724732,
#         "label": "positive"
#       },
#       "relevance": 0.521247,
#       "emotion": {
#         "sadness": 0.098599,
#         "joy": 0.778855,
#         "fear": 0.060311,
#         "disgust": 0.02391,
#         "anger": 0.023072
#       },
#       "count": 1
#     },
#     {
#       "text": "skywalk",
#       "sentiment": {
#         "score": 0.957978,
#         "label": "positive"
#       },
#       "relevance": 0.51725,
#       "emotion": {
#         "sadness": 0.026633,
#         "joy": 0.750424,
#         "fear": 0.052478,
#         "disgust": 0.023236,
#         "anger": 0.00606
#       },
#       "count": 1
#     },
#     {
#       "text": "way",
#       "sentiment": {
#         "score": -0.919753,
#         "label": "negative"
#       },
#       "relevance": 0.514534,
#       "emotion": {
#         "sadness": 0.212864,
#         "joy": 0.293073,
#         "fear": 0.115059,
#         "disgust": 0.108649,
#         "anger": 0.312103
#       },
#       "count": 1
#     },
#     {
#       "text": "real credit",
#       "sentiment": {
#         "score": 0.986622,
#         "label": "positive"
#       },
#       "relevance": 0.513904,
#       "emotion": {
#         "sadness": 0.115967,
#         "joy": 0.745994,
#         "fear": 0.053952,
#         "disgust": 0.017398,
#         "anger": 0.025789
#       },
#       "count": 1
#     },
#     {
#       "text": "whole site",
#       "sentiment": {
#         "score": 0.848073,
#         "label": "positive"
#       },
#       "relevance": 0.513904,
#       "emotion": {
#         "sadness": 0.142284,
#         "joy": 0.672585,
#         "fear": 0.048696,
#         "disgust": 0.124595,
#         "anger": 0.058746
#       },
#       "count": 1
#     },
#     {
#       "text": "place",
#       "sentiment": {
#         "score": -0.58405,
#         "label": "negative"
#       },
#       "relevance": 0.513667,
#       "emotion": {
#         "sadness": 0.235387,
#         "joy": 0.630328,
#         "fear": 0.027271,
#         "disgust": 0.010646,
#         "anger": 0.043987
#       },
#       "count": 1
#     },
#     {
#       "text": "city",
#       "sentiment": {
#         "score": 0.986622,
#         "label": "positive"
#       },
#       "relevance": 0.509887,
#       "emotion": {
#         "sadness": 0.115967,
#         "joy": 0.745994,
#         "fear": 0.053952,
#         "disgust": 0.017398,
#         "anger": 0.025789
#       },
#       "count": 1
#     },
#     {
#       "text": "attention",
#       "sentiment": {
#         "score": 0.92892,
#         "label": "positive"
#       },
#       "relevance": 0.509887,
#       "emotion": {
#         "sadness": 0.283477,
#         "joy": 0.162033,
#         "fear": 0.091824,
#         "disgust": 0.069525,
#         "anger": 0.226756
#       },
#       "count": 1
#     },
#     {
#       "text": "time",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.427428,
#       "emotion": {
#         "sadness": 0.158631,
#         "joy": 0.730448,
#         "fear": 0.042923,
#         "disgust": 0.012472,
#         "anger": 0.048767
#       },
#       "count": 2
#     }
#   ],
#   "entities": [
#     {
#       "type": "Company",
#       "text": "Google",
#       "sentiment": {
#         "score": -0.58405,
#         "label": "negative"
#       },
#       "relevance": 0.978348,
#       "emotion": {
#         "sadness": 0.356046,
#         "joy": 0.276475,
#         "fear": 0.042222,
#         "disgust": 0.020566,
#         "anger": 0.106622
#       },
#       "disambiguation": {
#         "subtype": [
#           "AcademicInstitution",
#           "AwardPresentingOrganization",
#           "OperatingSystemDeveloper",
#           "ProgrammingLanguageDeveloper",
#           "SoftwareDeveloper",
#           "VentureFundedCompany"
#         ],
#         "name": "Google",
#         "dbpedia_resource": "http://dbpedia.org/resource/Google"
#       },
#       "count": 1,
#       "confidence": 0.966746
#     }
#   ]
# }

# %%
keywords_col_names = ['WEBSITE_ID', 'REVIEW_ID', 'TEXT', 'RELEVANCE', 'COUNT',
                     'SENTIMENT_SCORE', 'SENTIMENT_LABEL', 'SADNESS', 'JOY',
                     'FEAR', 'DISGUST', 'ANGER', 'MIXED_SENTIMENT']

keywords_col_names_map = {
    'text': 'TEXT', 
    'relevance': 'RELEVANCE', 
    'count': 'COUNT', 
    'sentiment.score': 'SENTIMENT_SCORE',
    'sentiment.label': 'SENTIMENT_LABEL',
    'emotion.sadness': 'SADNESS',
    'emotion.joy': 'JOY',
    'emotion.fear': 'FEAR',
    'emotion.disgust': 'DISGUST',
    'emotion.anger': 'ANGER',
    'sentiment.mixed': 'MIXED_SENTIMENT'
}



keywords_df = json_normalize(response['keywords']).rename(columns=keywords_col_names_map)
keywords_df = keywords_df[keywords_col_names[2:]]
keywords_df.insert(0, 'REVIEW_INDEX', 1234567890)
keywords_df.insert(0, 'WEBSITE_ID', 1)
keywords_df
# Out:
#     WEBSITE_ID  REVIEW_INDEX              TEXT  RELEVANCE  COUNT  \
# 0            1    1234567890       Google maps   0.787506      1
# 1            1    1234567890   Christmas night   0.656920      1
# 2            1    1234567890       Flower Dome   0.636486      1
# 3            1    1234567890         long time   0.605059      1
# 4            1    1234567890       useful tool   0.602506      1
# 5            1    1234567890      Cloud Forest   0.601793      2
# 6            1    1234567890    stunning place   0.590876      1
# 7            1    1234567890      second visit   0.585235      1
# 8            1    1234567890       MRT station   0.577090      1
# 9            1    1234567890  paid attractions   0.566158      1
# 10           1    1234567890               Bay   0.544072      2
# 11           1    1234567890            dinner   0.542642      1
# 12           1    1234567890            Queues   0.540512      1
# 13           1    1234567890           Gardens   0.534535      1
# 14           1    1234567890             Satay   0.532580      1
# 15           1    1234567890           feature   0.523991      1
# 16           1    1234567890          decision   0.521247      1
# 17           1    1234567890           skywalk   0.517250      1
# 18           1    1234567890               way   0.514534      1
# 19           1    1234567890       real credit   0.513904      1
# 20           1    1234567890        whole site   0.513904      1
# 21           1    1234567890             place   0.513667      1
# 22           1    1234567890              city   0.509887      1
# 23           1    1234567890         attention   0.509887      1
# 24           1    1234567890              time   0.427428      2
#
#     SENTIMENT_SCORE SENTIMENT_LABEL   SADNESS       JOY      FEAR   DISGUST  \
# 0         -0.584050        negative  0.356046  0.276475  0.042222  0.020566
# 1          0.848073        positive  0.142284  0.672585  0.048696  0.124595
# 2          0.724732        positive  0.098599  0.778855  0.060311  0.023910
# 3          0.724732        positive  0.098599  0.778855  0.060311  0.023910
# 4          0.837360        positive  0.147367  0.558533  0.059763  0.102180
# 5          0.860140        positive  0.049122  0.858749  0.039461  0.020585
# 6          0.986622        positive  0.115967  0.745994  0.053952  0.017398
# 7          0.848073        positive  0.127068  0.301353  0.052929  0.144640
# 8         -0.777339        negative  0.212864  0.293073  0.115059  0.108649
# 9          0.928770        positive  0.032162  0.763132  0.028307  0.055176
# 10         0.410452        positive  0.137327  0.691357  0.053887  0.034470
# 11        -0.919753        negative  0.212864  0.293073  0.115059  0.108649
# 12         0.928770        positive  0.032162  0.763132  0.028307  0.055176
# 13         0.986622        positive  0.115967  0.745994  0.053952  0.017398
# 14        -0.919753        negative  0.212864  0.293073  0.115059  0.108649
# 15        -0.584050        negative  0.356046  0.276475  0.042222  0.020566
# 16         0.724732        positive  0.098599  0.778855  0.060311  0.023910
# 17         0.957978        positive  0.026633  0.750424  0.052478  0.023236
# 18        -0.919753        negative  0.212864  0.293073  0.115059  0.108649
# 19         0.986622        positive  0.115967  0.745994  0.053952  0.017398
# 20         0.848073        positive  0.142284  0.672585  0.048696  0.124595
# 21        -0.584050        negative  0.235387  0.630328  0.027271  0.010646
# 22         0.986622        positive  0.115967  0.745994  0.053952  0.017398
# 23         0.928920        positive  0.283477  0.162033  0.091824  0.069525
# 24         0.000000         neutral  0.158631  0.730448  0.042923  0.012472
#
#        ANGER MIXED_SENTIMENT
# 0   0.106622             NaN
# 1   0.058746             NaN
# 2   0.023072             NaN
# 3   0.023072             NaN
# 4   0.056833             NaN
# 5   0.012998             NaN
# 6   0.025789             NaN
# 7   0.043257             NaN
# 8   0.312103             NaN
# 9   0.060813             NaN
# 10  0.098064               1
# 11  0.312103             NaN
# 12  0.060813             NaN
# 13  0.025789             NaN
# 14  0.312103             NaN
# 15  0.106622             NaN
# 16  0.023072             NaN
# 17  0.006060             NaN
# 18  0.312103             NaN
# 19  0.025789             NaN
# 20  0.058746             NaN
# 21  0.043987             NaN
# 22  0.025789             NaN
# 23  0.226756             NaN
# 24  0.048767             NaN

# %%
entities_col_names = ['WEBSITE_ID', 'REVIEW_ID', 'TYPE', 'TEXT', 'RELEVANCE',
                      'COUNT', 'CONFIDENCE', 'SENTIMENT_SCORE',
                      'SENTIMENT_LABEL', 'SADNESS', 'JOY', 'FEAR', 'DISGUST',
                      'ANGER', 'DISAMBIGUATION_SUBTYPE', 'DISAMBIGUATION_NAME', 
                      'DISAMBIGUATION_RESOURCE']

entities_col_names_map = {
    'type': 'TYPE',
    'text': 'TEXT', 
    'relevance': 'RELEVANCE', 
    'count': 'COUNT',
    'confidence': 'CONFIDENCE',
    'sentiment.score': 'SENTIMENT_SCORE',
    'sentiment.label': 'SENTIMENT_LABEL',
    'emotion.sadness': 'SADNESS',
    'emotion.joy': 'JOY',
    'emotion.fear': 'FEAR',
    'emotion.disgust': 'DISGUST',
    'emotion.anger': 'ANGER',
    'sentiment.mixed': 'MIXED_SENTIMENT',
    'disambiguation.subtype': 'DISAMBIGUATION_SUBTYPE',
    'disambiguation.name': 'DISAMBIGUATION_NAME',
    'disambiguation.dbpedia_resource': 'DISAMBIGUATION_RESOURCE'
}

entities_df = json_normalize(response['entities']).rename(columns=entities_col_names_map)
entities_df.insert(0, 'REVIEW_INDEX', 1234567890)
entities_df.insert(0, 'WEBSITE_ID', 1)
entities_df
# Out:
#    WEBSITE_ID  REVIEW_INDEX     TYPE    TEXT  RELEVANCE  COUNT  CONFIDENCE  \
# 0           1    1234567890  Company  Google   0.978348      1    0.966746
#
#    SENTIMENT_SCORE SENTIMENT_LABEL   SADNESS       JOY      FEAR   DISGUST  \
# 0         -0.58405        negative  0.356046  0.276475  0.042222  0.020566
#
#       ANGER                             DISAMBIGUATION_SUBTYPE  \
# 0  0.106622  [AcademicInstitution, AwardPresentingOrganizat...
#
#   DISAMBIGUATION_NAME             DISAMBIGUATION_RESOURCE
# 0              Google  http://dbpedia.org/resource/Google
