# %%
import pandas as pd
import os

# %%
path = './output/200418_220323/sentiments_200420_111012'
fileList = os.listdir(path)

# %%
annotation=pd.read_csv(path+'/'+fileList[0])

# %%
for i in range(1,len(fileList)):
    to_append=pd.read_csv(path+'/'+fileList[i])
    annotation=annotation.append(to_append)

# %%
annotation
# Out:
#     ANGER API key 0 exhausted.  CONFIDENCE COUNT  DISAMBIGUATION_NAME  \
# 0     NaN                  NaN         NaN     1                  NaN
# 0     NaN                  NaN         NaN     1                  NaN
# 1     NaN                  NaN         NaN     1                  NaN
# 2     NaN                  NaN         NaN     1                  NaN
# 3     NaN                  NaN         NaN     1                  NaN
# ..    ...                  ...         ...   ...                  ...
# 15    NaN                  NaN         NaN     1                  NaN
# 16    NaN                  NaN         NaN     1                  NaN
# 17    NaN                  NaN         NaN     1                  NaN
# 18    NaN                  NaN         NaN     1                  NaN
# 19    NaN                  NaN         NaN     1                  NaN
#
#     DISAMBIGUATION_RESOURCE  DISAMBIGUATION_SUBTYPE  DISGUST  FEAR  JOY  \
# ...

# %%
annotation=annotation.drop(['ANGER',
                            'CONFIDENCE',
                            'DISAMBIGUATION_NAME',
                            'DISAMBIGUATION_RESOURCE',
                            'DISAMBIGUATION_SUBTYPE',
                            'DISGUST',
                            'FEAR',
                            'JOY',
                            'MIXED_SENTIMENT',
                            'SADNESS'],axis=1)

# %%
annotation.to_csv('./output/annotation.csv')

# %%
count=annotation.groupby(by='TEXT').count()

# %%
ToAnnotate= count.sort_values(by='COUNT',ascending=False)

# %%
ToAnnotate.to_csv('./output/ToAnnotate.csv')

# %%
path = './output/200418_220323/reviews'
fileList = os.listdir(path)
reviews=pd.read_csv(path+'/'+fileList[0])
for i in range(1,len(fileList)):
    to_append=pd.read_csv(path+'/'+fileList[i])
    reviews=reviews.append(to_append)
# Out:
# /home/jia/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
reviews.to_csv('./output/review.csv')

# %%
#integrate dictionary into the new annotation
dictionary=pd.read_csv('./output/vocab.csv')

# %%
ch_annotation=pd.read_csv('./output/combined_annotation.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-b293201616b7> in <module>
# ----> 1 ch_annotation=pd.read_csv('./output/combined_annotation.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
#data manipulation
annotation=pd.read_csv('./output/ch_pois_data/combined_annotation.csv')

# %%
keywords=pd.read_csv('./output/ch_pois_data/annotation.csv')

# %%
reviews=pd.read_csv('./output/ch_pois_data/review.csv')

# %%
combined=keywords.merge(reviews,how="left",on=['REVIEW_ID'])

# %%
ch_all_combined=combined.merge(annotation,how="left",on=['TEXT'])

# %%
ch_combined= ch_all_combined.drop_duplicates(keep="first")

# %%
ch_combined.to_csv('./output/ch_combined1.csv')
