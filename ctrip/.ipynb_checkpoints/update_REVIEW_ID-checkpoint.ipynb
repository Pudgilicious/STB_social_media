# %%
import pandas as pd

# %%
poi=pd.read_csv("./finalised_output/200216_102752/reviews/1.csv")

# %%
len(poi)
# Out:
# 3000

# %%
path="./finalised_output/200216_102752/reviews/"

# %%
record_len=[3000]
for i in range(2,519):
    try:
        data=pd.read_csv(path+"{}.csv".format(i))
        poi=poi.append(data)
        record_len+=[len(data)]
    except:
        print(str(i)+" does not exist")
# Out:
# 373 does not exist

# %%
poi.describe()
# Out:
#        REVIEW_INDEX  WEBSITE_INDEX     POI_INDEX  REVIEW_RATING
# count           0.0        67432.0  67432.000000   67432.000000
# mean            NaN            2.0     40.514133       4.618564
# std             NaN            0.0     63.832620       0.952912
# min             NaN            2.0      1.000000       0.000000
# 25%             NaN            2.0      7.000000       4.000000
# 50%             NaN            2.0     17.000000       5.000000
# 75%             NaN            2.0     41.000000       5.000000
# max             NaN            2.0    518.000000       9.000000

# %%
#insert review id
poi['REVIEW_INDEX']=list(range(1,len(poi)+1))
poi=poi.rename(columns={"REVIEW_INDEX": "REVIEW_ID"})

# %%
poi.head(20)
# Out:
#     REVIEW_ID  WEBSITE_INDEX  POI_INDEX  REVIEWER_NAME  REVIEW_RATING  \
# 0           1              2          1           考拉羊洋            5.0
# 1           2              2          1       Queenie劉            5.0
# 2           3              2          1  _CFT0****6916            5.0
# 3           4              2          1       goven814            4.0
# 4           5              2          1    M25****2831            4.0
# 5           6              2          1          西门吹水1            5.0
# 6           7              2          1     M48****413            5.0
# 7           8              2          1         杰杰陶TAO            5.0
# 8           9              2          1     M51****556            4.0
# 9          10              2          1         露小姐爱旅行            5.0
# 10         11              2          1         散香MKII            3.0
# 11         12              2          1         张森1314            2.0
# 12         13              2          1           大贤良师            4.0
# 13         14              2          1         antony            4.0
# 14         15              2          1    M35****3126            5.0
# 15         16              2          1    M34****4580            5.0
# 16         17              2          1    M33****2295            5.0
# 17         18              2          1    M33****9173            5.0
# 18         19              2          1           悠悠星空            5.0
# 19         20              2          1      BetTerDAY            5.0
#
#    REVIEW_DATE REVIEW_TIME                                        REVIEW_BODY  \
# 0   2019-08-12       03:58  新加坡环球影城 (USS) 位于圣淘沙名胜世界内，是东南亚首个也是唯一的一个环球影城主题公园...
# 1   2019-03-14       23:09  ✨新加坡&#183;环球影城✨ 必打卡❗️ 进入了另一个奇幻又可爱的世界 真的是从早嗨到晚，...
# 2   2019-05-04       23:18  作为一个世界级的游乐场，少不了的就是刺激，但与其它游乐场比起来，新加坡环球影城则是与众不同。...
# 3   2019-01-01       22:46  这个我给四星吧还是。我上午十点钟进去，下午两点钟出来了。感觉没有大阪的好。木乃伊归来和变形金...
# 4   2019-01-06       21:03  9点半左右到，门口拍两张照片，40分左右就有人排队了。非节假日人已经不算多，但是尽管一进去就...
# 5   2019-12-31       13:32  环球影城内的24个游乐设施和景点，各自精彩，其中包括深具创意和世界最高的双轨过山车，一人坐着...
# 6   2019-12-02       21:10  新加坡环球影城位于新加坡的圣淘沙度假岛上，这里绝对是新加坡最值得来的乐园。里面有许多环球电影...
# 7   2019-11-26       14:41  新加坡环球影城是东南亚第一座也是唯一的一座环球影城。它是继日本大阪环球影城之后，亚洲第二个环...
# 8   2019-04-12       16:52  1、一定要提前购买电子票，现场买票排队，天儿又热又晒！我买的是电子门票+一次性优先票，即一个...
# 9   2019-03-21       21:21  2019.03.20 一个人来到游乐园，度过了孤单而快乐的一天。小时候是多么想快点长大啊，现...
# 10  2019-10-07       16:57  园区很小，早上十点开门晚上六点就关闭了，如果有万圣节活动要另外买票才能参加夜场，这还是方面U...
# 11  2019-08-10       14:31  新加坡环球影视城很小，没有上海迪士尼的四分之一大，门票价格也不便宜，只不过宣传名气比较大，所...
# 12  2020-01-10       14:35  我觉得大家应该会关心这个环球影城和大阪的区别，严格来说区别很大，几乎没有重复的大项目，新加坡...
# 13  2019-10-07       15:35  来新加坡必须到环球影城打一次卡，相比迪士尼乐园，它更适合大一点的小朋友和大朋友们。机动游戏的...
# 14  2019-10-01       23:05  挺好的。也许不尽然是在一天之内。你真的需要好好计划你的一天，因为有很多地方值得去乘骑和观看以...
# 15  2019-09-10       23:24  大部份景物和游戏跟世界其他地方的Universal Studio大同小异，但星加坡这个比较小...
# 16  2019-09-10       13:32  在party go round 被一个印度家庭插队，向职员反映，她有跟那个家庭说了两句但他们...
# 17  2019-09-09       23:31  很多部落客都会分享里面的游乐设施，还有动线要怎么玩比较快， 像是逆时针走还是顺时针走之类的。...
# 18  2019-08-14       22:43  这里是新加坡必到景点，这里在寒暑假中国游客特别多，这里的游览项目都是从电影中取材，比较刺激的...
# 19  2019-11-20       13:28  新加坡环球影城刷新了我对4D的认知，原来我以前看到的4D效果都是假的变形金刚的身临其境感简直...
#
#        ATTRIBUTES_CRAWLED_TIME
# 0   2020-02-16 10:28:08.258128
# 1   2020-02-16 10:28:08.272729
# 2   2020-02-16 10:28:08.285601
# 3   2020-02-16 10:28:08.293030
# 4   2020-02-16 10:28:08.298688
# 5   2020-02-16 10:28:08.303211
# 6   2020-02-16 10:28:08.307175
# 7   2020-02-16 10:28:08.310814
# 8   2020-02-16 10:28:08.314054
# 9   2020-02-16 10:28:08.317169
# 10  2020-02-16 10:28:10.696898
# 11  2020-02-16 10:28:10.711982
# 12  2020-02-16 10:28:10.727344
# 13  2020-02-16 10:28:10.734571
# 14  2020-02-16 10:28:10.739994
# 15  2020-02-16 10:28:10.744598
# 16  2020-02-16 10:28:10.748674
# 17  2020-02-16 10:28:10.752437
# 18  2020-02-16 10:28:10.755767
# 19  2020-02-16 10:28:10.758964

# %%
# set the index to be this and don't drop
poi.set_index(keys=['POI_INDEX'], drop=False,inplace=True)
# get a list of names
names=poi['POI_INDEX'].unique().tolist()

# %%
for i in range(1,519):
    try:           
        new_csv=poi[poi['POI_INDEX']==i]
        new_csv.to_csv('./finalised_output/updated/{}.csv'.format(i),index=False)
    except:
        print(str(i)+" does not exist")
